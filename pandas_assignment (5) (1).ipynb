# %% [markdown]
# # Pandas Assignment

# %% [markdown]
# datsets: top songs of the year specified
#
# ---
#
#
#
#
# *   spotify_data_2011-2020.csv
# *   spotify_data_2021-1.csv

# %% [markdown]
# <h3 style="color:#1DB954">Variable description</h2>
#
# <table style=" background-color: #c9ffb8;
#               font-size:13px;
#               font-weight:normal;
#               border: 6px solid #4e7852;">
#   <tr style="border: 3px solid #4e7852 ;" >
#     <th>Variable</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>name </td>
#     <td>The name of the artist.</td>
#   </tr>
#   <tr>
#     <td>album</td>
#     <td>The album on which the track appears.</td>
#   </tr>
#    <tr>
#     <td>artist </td>
#     <td>The artists who performed the track.</td>
#    </tr>
#     <tr>
#     <td>release_date         </td>
#     <td>The date the album was first released, for example 1981. Depending on the precision, it might be shown as 1981-12 or 1981-12-15.</td>
#    </tr>
#    <tr>
#     <td> length	 </td>
#     <td>The track length in milliseconds.</td>
#    </tr>
#     <tr>
#     <td> popularity	    </td>
#     <td>The popularity of the artist. The value will be between 0 and 100, with 100 being the most       popular.The artist’s popularity is calculated from the popularity of all the artist’s tracks.</td>
#    </tr>
#      <tr>
#      <td>explicit               </td>
#     <td>Whether or not the show has explicit content (true = yes it does; false = no it does not OR unknown).</td>
#    </tr>
#      <tr>
#     <td> danceability        </td>
#     <td> Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.</td>
#    </tr>
#      <tr>
#     <td> tempo 	 </td>
#     <td>The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.</td>
#    </tr>
#      <tr>
#     <td> valence	 </td>
#     <td>A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry). </td>
#    </tr>
#      <tr>
#     <td>
#    acousticness	 </td>
#     <td>	A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.</td>
#    </tr>
#     <tr>
#     <td>energy 	 </td>
#     <td>Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.</td>
#    </tr>
#     <tr>
#     <td> instrumentalness 	 </td>
#     <td>Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.</td>
#    </tr>
#     <tr>
#     <td>liveness	 </td>
#     <td>This value describes the probability that the song was recorded with a live audience. According to the official documentation “a value above 0.8 provides strong likelihood that the track is live”..</td>
#    </tr>
#     <tr>
#     <td>loudness </td>
#     <td>The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.	</td>
#    </tr>
#     <tr>
#     <td>speechiness </td>
#     <td>Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.</td>
#    </tr>
#     <tr>
#         <td>mode</td>
# <td>Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.</td>
#     </tr>
#
#
# </table>
# <style>
#
#
# </style>
# <p>For more info, check the developers website created by <a href="https://developer.spotify.com/documentation/web-api/reference/#category-tracks" >Spotify </a>

# %% [markdown]
# ## import pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Read spotify_2011-2020.csv file

# %%
data=pd.read_csv("spotify_data_2011-2020.csv")

# %% [markdown]
# ## Display first 10 rows of the dataset

# %%
data.head(10)
# Out:
#                                             name         artists  \
# 0                          Old Town Road - Remix       Lil Nas X
# 1                                        bad guy   Billie Eilish
# 2                                       Señorita    Shawn Mendes
# 3                                        7 rings   Ariana Grande
# 4  Sunflower - Spider-Man: Into the Spider-Verse     Post Malone
# 5                                i'm so tired...            Lauv
# 6                                     Without Me          Halsey
# 7                                Don't Start Now        Dua Lipa
# 8                                        Shallow       Lady Gaga
# 9                                         Sucker  Jonas Brothers
#
#                        id release_date  explicit  valence  acousticness  \
# 0  2YpeDb67231RjR0MgVLzsG   21-06-2019     False    0.639        0.0533
# 1  2Fxmhks0bxGSBdJ92vM42m   29-03-2019     False    0.562        0.3280
# ...

# %% [markdown]
# ## Display 4 rows from the last

# %%
data.tail(4)
# Out:
#                                 name        artists                      id  \
# 880                        Honey Bee  Blake Shelton  0U3xEfWLX4slslHJaAorSw
# 881         Stereo Love - Radio Edit    Edward Maya  1AguHaKOuggrVTebp7cZEI
# 882                 Black and Yellow    Wiz Khalifa  5A6OHHy73AR5tLxgTc98zz
# 883  Earthquake (feat. Tinie Tempah)       Labrinth  3SxiAdI8dP9AaaEz1Z24mn
#
#     release_date  explicit  valence  acousticness  danceability  duration_ms  \
# 880   12-07-2011     False    0.723       0.00167         0.481       210720
# 881   02-02-2010     False    0.586       0.03460         0.799       184573
# 882   29-03-2011      True    0.538       0.06460         0.684       217666
# 883   02-04-2012      True    0.258       0.10900         0.540       274600
#
#      energy  instrumentalness  loudness  key  liveness  mode  popularity  \
# 880   0.849          0.000001    -5.131    4    0.1210     1          50
# ...

# %% [markdown]
# ## Display the information of each column in the dataset using .info function

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884 entries, 0 to 883
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              884 non-null    object
#  1   artists           884 non-null    object
#  2   id                884 non-null    object
#  3   release_date      884 non-null    object
#  4   explicit          884 non-null    bool
#  5   valence           884 non-null    float64
#  6   acousticness      884 non-null    float64
#  7   danceability      884 non-null    float64
#  8   duration_ms       884 non-null    int64
#  9   energy            884 non-null    float64
#  10  instrumentalness  884 non-null    float64
#  11  loudness          884 non-null    float64
#  12  key               884 non-null    int64
#  13  liveness          884 non-null    float64
#  14  mode              884 non-null    int64
#  15  popularity        884 non-null    int64
# ...

# %% [markdown]
# ## Check for null values

# %%
data.isnull().sum()
# Out:
# name                0
# artists             0
# id                  0
# release_date        0
# explicit            0
# valence             0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# loudness            0
# key                 0
# liveness            0
# mode                0
# popularity          0
# speechiness         0
# tempo               0
# year                0
# dtype: int64

# %% [markdown]
# ## Display the number of unique values in each column using .nunique function

# %%
data.nunique()
# Out:
# name                843
# artists             371
# id                  883
# release_date        458
# explicit              2
# valence             543
# acousticness        691
# danceability        407
# duration_ms         848
# energy              449
# instrumentalness    327
# loudness            806
# key                  12
# liveness            458
# mode                  2
# popularity           65
# speechiness         566
# tempo               838
# year                 12
# dtype: int64

# %% [markdown]
# ## Identify the columns with **numeric values** and display those

# %%
import numpy as np
data_numerics_only = data.select_dtypes(include = np.number)
data_numerics_only
# Out:
#      valence  acousticness  danceability  duration_ms  energy  \
# 0      0.639       0.05330         0.878       157066   0.619
# 1      0.562       0.32800         0.701       194087   0.425
# 2      0.749       0.03920         0.759       190799   0.548
# 3      0.327       0.59200         0.778       178626   0.317
# 4      0.925       0.53300         0.755       157560   0.522
# ..       ...           ...           ...          ...     ...
# 879    0.927       0.10000         0.692       263386   0.809
# 880    0.723       0.00167         0.481       210720   0.849
# 881    0.586       0.03460         0.799       184573   0.783
# 882    0.538       0.06460         0.684       217666   0.834
# 883    0.258       0.10900         0.540       274600   0.856
#
#      instrumentalness  loudness  key  liveness  mode  popularity  speechiness  \
# 0            0.000000    -5.560    6    0.1130     1          80       0.1020
# ...

# %% [markdown]
# ## Display the statistical information of the numerical columns

# %%
data_numerics_only.describe()
# Out:
#           valence  acousticness  danceability    duration_ms      energy  \
# count  884.000000    884.000000    884.000000     884.000000  884.000000
# mean     0.515144      0.157587      0.660261  216767.647059    0.692423
# std      0.216215      0.204578      0.123391   36857.603416    0.157826
# min      0.038100      0.000132      0.209000  113000.000000    0.056500
# 25%      0.352000      0.020000      0.589000  196460.000000    0.588000
# 50%      0.514000      0.073650      0.671500  214493.000000    0.714000
# 75%      0.674000      0.213000      0.743000  232949.250000    0.810000
# max      0.966000      0.978000      0.964000  688453.000000    0.985000
#
#        instrumentalness    loudness         key    liveness        mode  \
# count        884.000000  884.000000  884.000000  884.000000  884.000000
# mean           0.006235   -5.546149    5.296380    0.170584    0.583710
# std            0.052388    1.869334    3.568192    0.126696    0.493222
# ...

# %% [markdown]
# ## Display the  columns with categorical  values

# %% [markdown]
# ## Display all the colunns  with continuous value

# %%
data.loc[:,['valence', 'acousticness', 'danceability', 'energy' , 'instrumentalness' , 'loudness', 'liveness', 'popularity', 'speechiness', 'tempo']]
# Out:
#      valence  acousticness  danceability  energy  instrumentalness  loudness  \
# 0      0.639       0.05330         0.878   0.619          0.000000    -5.560
# 1      0.562       0.32800         0.701   0.425          0.130000   -10.965
# 2      0.749       0.03920         0.759   0.548          0.000000    -6.049
# 3      0.327       0.59200         0.778   0.317          0.000000   -10.732
# 4      0.925       0.53300         0.755   0.522          0.000000    -4.368
# ..       ...           ...           ...     ...               ...       ...
# 879    0.927       0.10000         0.692   0.809          0.000098    -5.935
# 880    0.723       0.00167         0.481   0.849          0.000001    -5.131
# 881    0.586       0.03460         0.799   0.783          0.018600    -3.896
# 882    0.538       0.06460         0.684   0.834          0.000000    -4.524
# 883    0.258       0.10900         0.540   0.856          0.000000    -3.966
#
# ...

# %% [markdown]
# ## Display the first 3 columns using iloc function (all the rows )

# %%
data.iloc[0:3]
# Out:
#                     name        artists                      id release_date  \
# 0  Old Town Road - Remix      Lil Nas X  2YpeDb67231RjR0MgVLzsG   21-06-2019
# 1                bad guy  Billie Eilish  2Fxmhks0bxGSBdJ92vM42m   29-03-2019
# 2               Señorita   Shawn Mendes  6v3KW9xbzN5yKLt9YKDYA2   19-06-2019
#
#    explicit  valence  acousticness  danceability  duration_ms  energy  \
# 0     False    0.639        0.0533         0.878       157066   0.619
# 1     False    0.562        0.3280         0.701       194087   0.425
# 2     False    0.749        0.0392         0.759       190799   0.548
#
#    instrumentalness  loudness  key  liveness  mode  popularity  speechiness  \
# 0              0.00    -5.560    6    0.1130     1          80        0.102
# 1              0.13   -10.965    7    0.1000     1          85        0.375
# 2              0.00    -6.049    9    0.0828     0          79        0.029
#
#      tempo  year
# 0  136.041  2019
# 1  135.128  2019
# ...

# %% [markdown]
# ## Display name of the song, the artist ,the release date and popularity columns using loc function

# %%
selection = data.loc[:,['name', 'artists', 'release_date', 'popularity']]
print(selection)
# Out:
#                                               name        artists  \
# 0                            Old Town Road - Remix      Lil Nas X
# 1                                          bad guy  Billie Eilish
# 2                                         Señorita   Shawn Mendes
# 3                                          7 rings  Ariana Grande
# 4    Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# ..                                             ...            ...
# 879                                    Springsteen    Eric Church
# 880                                      Honey Bee  Blake Shelton
# 881                       Stereo Love - Radio Edit    Edward Maya
# 882                               Black and Yellow    Wiz Khalifa
# 883                Earthquake (feat. Tinie Tempah)       Labrinth
#
#     release_date  popularity
# 0     21-06-2019          80
# 1     29-03-2019          85
# 2     19-06-2019          79
# 3     08-02-2019          85
# ...

# %% [markdown]
# ## Find duplicate rows in the dataset

# %%
duplicaterows = data[data.duplicated()]
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 879    False
# 880    False
# 881    False
# 882    False
# 883     True
# Length: 884, dtype: bool

# %% [markdown]
# ## Drop the duplicate rows

# %%
result_df = data.drop_duplicates(keep=False)
result_df
# Out:
#                                               name        artists  \
# 0                            Old Town Road - Remix      Lil Nas X
# 1                                          bad guy  Billie Eilish
# 2                                         Señorita   Shawn Mendes
# 3                                          7 rings  Ariana Grande
# 4    Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# ..                                             ...            ...
# 878                                  Sweat - Remix     Snoop Dogg
# 879                                    Springsteen    Eric Church
# 880                                      Honey Bee  Blake Shelton
# 881                       Stereo Love - Radio Edit    Edward Maya
# 882                               Black and Yellow    Wiz Khalifa
#
#                          id release_date  explicit  valence  acousticness  \
# 0    2YpeDb67231RjR0MgVLzsG   21-06-2019     False    0.639       0.05330
# ...

# %% [markdown]
# ## Group the songs by year and explicit values and display the average popularity of song in each group
#   hint = groupy year and explicit column. Find the average of popularity for each group.For better understanding [  CLICK HERE](https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/)

# %%
data.groupby(data.year).agg('count')
# Out:
#       name  artists   id  release_date  explicit  valence  acousticness  \
# year
# 2009     1        1    1             1         1        1             1
# 2010    29       29   29            29        29       29            29
# 2011    76       76   76            76        76       76            76
# 2012   109      109  109           109       109      109           109
# 2013    76       76   76            76        76       76            76
# 2014    96       96   96            96        96       96            96
# 2015    88       88   88            88        88       88            88
# 2016    88       88   88            88        88       88            88
# 2017   105      105  105           105       105      105           105
# 2018    88       88   88            88        88       88            88
# 2019   103      103  103           103       103      103           103
# 2020    25       25   25            25        25       25            25
#
# ...

# %% [markdown]
# ## Display the name of the artist with highest number of occcurance with the number of occcurances .

# %%
data['artists'].describe()
# Out:
# count              884
# unique             371
# top       Taylor Swift
# freq                18
# Name: artists, dtype: object

# %% [markdown]
# ## Display the song name, artist and release date of the song with popularity more than 50.

# %%
a = data.loc[:,['name','artists','popularity']]
b = a[(a['popularity'] > 50)]
b
# Out:
#                                               name        artists  popularity
# 0                            Old Town Road - Remix      Lil Nas X          80
# 1                                          bad guy  Billie Eilish          85
# 2                                         Señorita   Shawn Mendes          79
# 3                                          7 rings  Ariana Grande          85
# 4    Sunflower - Spider-Man: Into the Spider-Verse    Post Malone          80
# ..                                             ...            ...         ...
# 878                                  Sweat - Remix     Snoop Dogg          65
# 879                                    Springsteen    Eric Church          72
# 881                       Stereo Love - Radio Edit    Edward Maya          64
# 882                               Black and Yellow    Wiz Khalifa          75
# 883                Earthquake (feat. Tinie Tempah)       Labrinth          61
#
# [732 rows x 3 columns]

# %% [markdown]
# ## Read the dataset spotify_data_2021-1

# %%
df=pd.read_csv('spotify_data_2021_1.csv')

# %% [markdown]
# ## The  given datasets have the same number of columns? Use shape function. Before concatenating check for the missing column ( the column that is there in spotify_data_2011-2020.csv but not in spotify_data_2021-1.csv)

# %%
print(df.shape)
# Out:
# (100, 19)

# %% [markdown]
# ## Create the missing column in the new dataset. Find the hint at the end of the Notebook.

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['Year'] = df['release_date'].dt.year
df
# Out:
#                                                  name        artists  \
# 0                                          Easy On Me          Adele
# 1                           LA FAMA (with The Weeknd)        ROSALÍA
# 2                                               Woman       Doja Cat
# 3                                           Oh My God          Adele
# 4                                         ESCAPE PLAN   Travis Scott
# ..                                                ...            ...
# 95                                  WHOLE LOTTA MONEY            BIA
# 96  Not In The Mood (feat. Fivio Foreign & Kay Flock)       Lil Tjay
# 97                                          positions  Ariana Grande
# 98                   death bed (coffee for your head)          Powfu
# 99                                             DÁKITI      Bad Bunny
#
#                         id release_date  explicit  valence  acousticness  \
# ...

# %% [markdown]
# ## Concatenate the new songs of 2021 with the existing dataset

# %% [markdown]
# ## Arrange the songs with increasing order with respect to energy

# %% [markdown]
# #The values in release date column is in the format dd-mm-yyyy extract the year from each of the value to vcreate a new column
